# %%
import logging as mr
mr.basicConfig(level=mr.DEBUG)

def sub(x,y):
    mr.debug("variables are %s and %s",x,y)
    return x-y

# %%
sub(10,12)
# Out:
# -2

# %%
import os
import datetime
import cv2

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'r:\python ds\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
